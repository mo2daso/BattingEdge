# %%
# ============================================================
# BattingEdge V9.5 - BIDIRECTIONAL GRU Model Training
# Features: 99 raw pose + 8 angles (NO velocities)
# Target: 83-86% accuracy
# ============================================================

# ✅ FIX: Import Pandas first to prevent circular import errors
import pandas as pd 
import numpy as np
import pickle
from pathlib import Path
from sklearn.utils.class_weight import compute_class_weight
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import json
import joblib

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense, Dropout, Bidirectional, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.optimizers import Adam

# ================= CONFIG =================
FEATURE_DIR = Path(r"D:\Users\Anoshia\BattingEdge_FYP\features")
MODEL_DIR   = Path(r"D:\Users\Anoshia\BattingEdge_FYP\backend\models")
MODEL_DIR.mkdir(parents=True, exist_ok=True)

ALGO_NAME = "bigru"  # Algorithm Name

EPOCHS = 60
BATCH_SIZE = 16
LEARNING_RATE = 5e-4 
# ==========================================

print("="*70)
print(f"BATTINGEDGE V9.5 - MODEL TRAINING ({ALGO_NAME.upper()})")
print("="*70)
print()

# ================= LOAD DATA =================
print("📂 Loading data...")

try:
    X_train = np.load(FEATURE_DIR / "X_train.npy")
    y_train = np.load(FEATURE_DIR / "y_train.npy")
    X_val   = np.load(FEATURE_DIR / "X_val.npy")
    y_val   = np.load(FEATURE_DIR / "y_val.npy")
    X_test  = np.load(FEATURE_DIR / "X_test.npy")
    y_test  = np.load(FEATURE_DIR / "y_test.npy")

    with open(FEATURE_DIR / "classes.pkl", "rb") as f:
        CLASSES = pickle.load(f)
except FileNotFoundError as e:
    print(f"\n❌ CRITICAL ERROR: Could not find data files.")
    print(f"   Checked directory: {FEATURE_DIR}")
    raise e

num_classes = len(CLASSES)
T, F = X_train.shape[1], X_train.shape[2]

print(f"Train: {X_train.shape[0]} samples")
print(f"Val:   {X_val.shape[0]} samples")
print(f"Test:  {X_test.shape[0]} samples")
print(f"Classes: {CLASSES}")
print(f"Features per frame: {F}")
print()

# ================= CRITICAL: SCALING =================
print("⚖️  Applying StandardScaler...")

scaler = StandardScaler()

# Fit on training data (flatten to 2D)
N_train = X_train.shape[0]
X_train_2d = X_train.reshape(N_train * T, F)
scaler.fit(X_train_2d)

def scale_data(X):
    N, T, F = X.shape
    X_2d = X.reshape(N * T, F)
    X_scaled = scaler.transform(X_2d)
    return X_scaled.reshape(N, T, F)

X_train = scale_data(X_train)
X_val   = scale_data(X_val)
X_test  = scale_data(X_test)

# Save scaler
scaler_path = MODEL_DIR / f"scaler_V9_5_{ALGO_NAME}.pkl"
classes_path = MODEL_DIR / f"classes_V9_5_{ALGO_NAME}.pkl"
joblib.dump(scaler, scaler_path)
joblib.dump(CLASSES, classes_path)
print(f"✅ Scaler saved: {scaler_path.name}")
print()

# ================= CLASS WEIGHTS =================
print("⚖️  Computing class weights...")

class_weights = compute_class_weight(
    class_weight="balanced",
    classes=np.arange(num_classes),
    y=y_train
)
class_weight_dict = dict(enumerate(class_weights))
print("   Weights loaded.")
print()

# ================= MODEL: Bi-GRU =================
print("🏗️  Building Bi-GRU model...")

model = Sequential([
    # Input - BiGRU instead of BiLSTM
    # GRU is generally faster and less prone to overfitting on smaller datasets
    Bidirectional(GRU(128, return_sequences=True, recurrent_dropout=0.2), 
                  input_shape=(T, F)),
    Dropout(0.4),
    
    # Second BiGRU Layer
    Bidirectional(GRU(64, recurrent_dropout=0.2)),
    Dropout(0.4),
    
    # Dense layers
    Dense(64, activation="relu"),
    BatchNormalization(),
    Dropout(0.3),
    
    # Output
    Dense(num_classes, activation="softmax")
])

model.compile(
    optimizer=Adam(learning_rate=LEARNING_RATE),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

model.summary()
print()

# ================= CALLBACKS =================
print("⚙️  Setting up callbacks...")

checkpoint_path = MODEL_DIR / f"battingedge_V9_5_{ALGO_NAME}_best.keras"

callbacks_list = [
    EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=True, verbose=1),
    ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=5, min_lr=1e-6, verbose=1),
    ModelCheckpoint(str(checkpoint_path), monitor="val_accuracy", save_best_only=True, verbose=1)
]

print(f"✅ Checkpoint: {checkpoint_path.name}")
print()

# ================= TRAINING =================
print("="*70)
print("🚀 STARTING TRAINING")
print("="*70)
print()

history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    class_weight=class_weight_dict,
    callbacks=callbacks_list,
    verbose=1
)

print()
print("="*70)
print("✅ TRAINING COMPLETE")
print("="*70)
print()

# Save final model
final_path = MODEL_DIR / f"battingedge_V9_5_{ALGO_NAME}_final.keras"
model.save(final_path)
print(f"💾 Saved final model: {final_path.name}")
print()

# ================= EVALUATION =================
print("="*70)
print("📊 EVALUATING ON TEST SET")
print("="*70)
print()

# Load best model
best_model = tf.keras.models.load_model(str(checkpoint_path))
print(f"✅ Loaded best model from: {checkpoint_path.name}")
print()

# Predict
y_pred = np.argmax(best_model.predict(X_test, verbose=0), axis=1)

# Classification report
print("📋 CLASSIFICATION REPORT:")
print()
report = classification_report(y_test, y_pred, target_names=CLASSES, digits=3)
print(report)

report_path = MODEL_DIR / f"report_V9_5_{ALGO_NAME}.txt"
with open(report_path, "w") as f:
    f.write(report)
print(f"✅ Report saved: {report_path.name}")
print()

# Confusion matrix
cm = confusion_matrix(y_test, y_pred)

print("🔢 CONFUSION MATRIX:")
print("   (Rows = True, Cols = Predicted)")
print()
print("        ", "  ".join([f"{cls[:4]:>4s}" for cls in CLASSES]))
for i, cls in enumerate(CLASSES):
    print(f"{cls[:8]:8s}", "  ".join([f"{cm[i,j]:4d}" for j in range(num_classes)]))
print()

# Per-class accuracy
print("📈 PER-CLASS ACCURACY:")
print()
for i, cls in enumerate(CLASSES):
    correct = cm[i, i]
    total = cm[i, :].sum()
    accuracy = (correct / total * 100) if total > 0 else 0
    print(f"   {cls:15s}: {correct:3d}/{total:3d} = {accuracy:5.1f}%")

overall_acc = np.trace(cm) / np.sum(cm) * 100
print()
print(f"   {'OVERALL':15s}: {np.trace(cm):3d}/{np.sum(cm):3d} = {overall_acc:5.2f}%")
print()

# Major confusions
print("🔍 MAJOR CONFUSIONS (>3 cases):")
print()
confusions = []
for i in range(num_classes):
    for j in range(num_classes):
        if i != j and cm[i, j] > 3:
            confusions.append((CLASSES[i], CLASSES[j], cm[i, j]))

if confusions:
    confusions.sort(key=lambda x: x[2], reverse=True)
    for true_cls, pred_cls, count in confusions:
        print(f"   {true_cls:15s} → {pred_cls:15s}: {count} cases")
else:
    print("   ✅ No major confusions!")
print()

# ================= VISUALIZATIONS =================
print("📊 Generating visualizations...")

# Confusion matrix heatmap
cm_path = MODEL_DIR / f"confusion_matrix_V9_5_{ALGO_NAME}.png"
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=CLASSES, yticklabels=CLASSES)
plt.title(f"Confusion Matrix - V9.5 ({ALGO_NAME})", fontsize=14, fontweight='bold')
plt.ylabel("True Label")
plt.xlabel("Predicted Label")
plt.tight_layout()
plt.savefig(cm_path, dpi=300)
print(f"   ✅ Saved: {cm_path.name}")
plt.close()

# Training history
history_path = MODEL_DIR / f"training_history_V9_5_{ALGO_NAME}.png"
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Val')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Model Accuracy')
plt.legend()
plt.grid(True, alpha=0.3)

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Val')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Model Loss')
plt.legend()
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig(history_path, dpi=300)
print(f"   ✅ Saved: {history_path.name}")
plt.close()

print()

# ================= METADATA =================
print("="*70)
print(f"🎉 V9.5 ({ALGO_NAME}) TRAINING COMPLETE")
print("="*70)
print()

# Save metadata
metadata = {
    "version": "V9.5",
    "algorithm": ALGO_NAME,
    "features": "99 raw pose + 8 angles (no velocities)",
    "classes": CLASSES,
    "test_accuracy": float(overall_acc),
    "per_class_accuracy": {
        CLASSES[i]: float((cm[i,i] / cm[i,:].sum() * 100) if cm[i,:].sum() > 0 else 0)
        for i in range(num_classes)
    },
    "hyperparameters": {
        "epochs": EPOCHS,
        "batch_size": BATCH_SIZE,
        "learning_rate": LEARNING_RATE
    }
}

metadata_path = MODEL_DIR / f"metadata_V9_5_{ALGO_NAME}.json"
with open(metadata_path, "w") as f:
    json.dump(metadata, f, indent=2)

print("📦 Saved artifacts:")
print(f"   1. Best model: {checkpoint_path.name}")
print(f"   2. Final model: {final_path.name}")
print(f"   3. Metadata: {metadata_path.name}")
print()

if overall_acc >= 83:
    print("✨ EXCELLENT RESULT! GRU is efficient and accurate.")
elif overall_acc >= 81:
    print("✅ GOOD RESULT. Competitive with LSTM.")
else:
    print("⚠️ Below target. Check feature extraction.")

print("="*70)
# Out:
# ======================================================================
# BATTINGEDGE V9.5 - MODEL TRAINING (BIGRU)
# ======================================================================
#
# 📂 Loading data...
# Train: 3007 samples
# Val:   388 samples
# Test:  378 samples
# Classes: ['Cover Drive', 'Cut Shot', 'Defense', 'Pull Shot', 'Sweep Shot']
# Features per frame: 107
#
# ⚖️  Applying StandardScaler...
# ✅ Scaler saved: scaler_V9_5_bigru.pkl
#
# ⚖️  Computing class weights...
#    Weights loaded.
#
# 🏗️  Building Bi-GRU model...
# d:\Users\Anoshia\BattingEdge_FYP\venv\Lib\site-packages\keras\src\layers\rnn\bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ bidirectional (Bidirectional)   │ (None, 50, 256)        │       182,016 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 50, 256)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_1 (Bidirectional) │ (None, 128)            │       123,648 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 5)              │           325 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 314,501 (1.20 MB)
#  Trainable params: 314,373 (1.20 MB)
#  Non-trainable params: 128 (512.00 B)
# ⚙️  Setting up callbacks...
# ✅ Checkpoint: battingedge_V9_5_bigru_best.keras
#
# ======================================================================
# 🚀 STARTING TRAINING
# ======================================================================
#
# Epoch 1/60
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - accuracy: 0.2897 - loss: 1.9975
# Epoch 1: val_accuracy improved from None to 0.47938, saving model to D:\Users\Anoshia\BattingEdge_FYP\backend\models\battingedge_V9_5_bigru_best.keras
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 101s 315ms/step - accuracy: 0.3422 - loss: 1.8087 - val_accuracy: 0.4794 - val_loss: 1.2782 - learning_rate: 5.0000e-04
# Epoch 2/60
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - accuracy: 0.4206 - loss: 1.4800
# Epoch 2: val_accuracy improved from 0.47938 to 0.54124, saving model to D:\Users\Anoshia\BattingEdge_FYP\backend\models\battingedge_V9_5_bigru_best.keras
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 75s 286ms/step - accuracy: 0.4493 - loss: 1.4205 - val_accuracy: 0.5412 - val_loss: 1.1282 - learning_rate: 5.0000e-04
# Epoch 3/60
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step - accuracy: 0.5203 - loss: 1.2142
# Epoch 3: val_accuracy improved from 0.54124 to 0.58763, saving model to D:\Users\Anoshia\BattingEdge_FYP\backend\models\battingedge_V9_5_bigru_best.keras
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 56s 299ms/step - accuracy: 0.5298 - loss: 1.1993 - val_accuracy: 0.5876 - val_loss: 1.0558 - learning_rate: 5.0000e-04
# Epoch 4/60
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step - accuracy: 0.5756 - loss: 1.0839
# Epoch 4: val_accuracy improved from 0.58763 to 0.67784, saving model to D:\Users\Anoshia\BattingEdge_FYP\backend\models\battingedge_V9_5_bigru_best.keras
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 76s 267ms/step - accuracy: 0.5823 - loss: 1.0866 - val_accuracy: 0.6778 - val_loss: 0.8806 - learning_rate: 5.0000e-04
# Epoch 5/60
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - accuracy: 0.6297 - loss: 0.9782
# Epoch 5: val_accuracy improved from 0.67784 to 0.68814, saving model to D:\Users\Anoshia\BattingEdge_FYP\backend\models\battingedge_V9_5_bigru_best.keras
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 52s 276ms/step - accuracy: 0.6325 - loss: 0.9711 - val_accuracy: 0.6881 - val_loss: 0.8328 - learning_rate: 5.0000e-04
# Epoch 6/60
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step - accuracy: 0.6778 - loss: 0.9009
# Epoch 6: val_accuracy improved from 0.68814 to 0.72423, saving model to D:\Users\Anoshia\BattingEdge_FYP\backend\models\battingedge_V9_5_bigru_best.keras
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 53s 281ms/step - accuracy: 0.6804 - loss: 0.8898 - val_accuracy: 0.7242 - val_loss: 0.7551 - learning_rate: 5.0000e-04
# Epoch 7/60
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - accuracy: 0.6937 - loss: 0.8226
# Epoch 7: val_accuracy improved from 0.72423 to 0.73196, saving model to D:\Users\Anoshia\BattingEdge_FYP\backend\models\battingedge_V9_5_bigru_best.keras
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 66s 352ms/step - accuracy: 0.7030 - loss: 0.8043 - val_accuracy: 0.7320 - val_loss: 0.7452 - learning_rate: 5.0000e-04
# Epoch 8/60
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step - accuracy: 0.7333 - loss: 0.7454
# Epoch 8: val_accuracy improved from 0.73196 to 0.76289, saving model to D:\Users\Anoshia\BattingEdge_FYP\backend\models\battingedge_V9_5_bigru_best.keras
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 54s 288ms/step - accuracy: 0.7369 - loss: 0.7329 - val_accuracy: 0.7629 - val_loss: 0.6575 - learning_rate: 5.0000e-04
# Epoch 9/60
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step - accuracy: 0.7658 - loss: 0.6647
# Epoch 9: val_accuracy did not improve from 0.76289
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 53s 280ms/step - accuracy: 0.7572 - loss: 0.6947 - val_accuracy: 0.7577 - val_loss: 0.6745 - learning_rate: 5.0000e-04
# Epoch 10/60
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.7614 - loss: 0.6583
# Epoch 10: val_accuracy improved from 0.76289 to 0.77062, saving model to D:\Users\Anoshia\BattingEdge_FYP\backend\models\battingedge_V9_5_bigru_best.keras
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 53s 280ms/step - accuracy: 0.7705 - loss: 0.6459 - val_accuracy: 0.7706 - val_loss: 0.6146 - learning_rate: 5.0000e-04
# Epoch 11/60
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step - accuracy: 0.7819 - loss: 0.5973
# Epoch 11: val_accuracy improved from 0.77062 to 0.77577, saving model to D:\Users\Anoshia\BattingEdge_FYP\backend\models\battingedge_V9_5_bigru_best.keras
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 82s 279ms/step - accuracy: 0.7862 - loss: 0.5974 - val_accuracy: 0.7758 - val_loss: 0.5689 - learning_rate: 5.0000e-04
# Epoch 12/60
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step - accuracy: 0.7963 - loss: 0.5534
# Epoch 12: val_accuracy improved from 0.77577 to 0.78866, saving model to D:\Users\Anoshia\BattingEdge_FYP\backend\models\battingedge_V9_5_bigru_best.keras
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 53s 284ms/step - accuracy: 0.8048 - loss: 0.5533 - val_accuracy: 0.7887 - val_loss: 0.5846 - learning_rate: 5.0000e-04
# Epoch 13/60
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step - accuracy: 0.8346 - loss: 0.4856
# Epoch 13: val_accuracy improved from 0.78866 to 0.80928, saving model to D:\Users\Anoshia\BattingEdge_FYP\backend\models\battingedge_V9_5_bigru_best.keras
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 82s 283ms/step - accuracy: 0.8251 - loss: 0.5066 - val_accuracy: 0.8093 - val_loss: 0.5386 - learning_rate: 5.0000e-04
# Epoch 14/60
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step - accuracy: 0.8431 - loss: 0.4457
# Epoch 14: val_accuracy did not improve from 0.80928
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 81s 277ms/step - accuracy: 0.8301 - loss: 0.4753 - val_accuracy: 0.7990 - val_loss: 0.5050 - learning_rate: 5.0000e-04
# Epoch 15/60
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step - accuracy: 0.8438 - loss: 0.4481
# Epoch 15: val_accuracy did not improve from 0.80928
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 83s 281ms/step - accuracy: 0.8400 - loss: 0.4420 - val_accuracy: 0.8067 - val_loss: 0.5353 - learning_rate: 5.0000e-04
# Epoch 16/60
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - accuracy: 0.8596 - loss: 0.3901
# Epoch 16: val_accuracy improved from 0.80928 to 0.85052, saving model to D:\Users\Anoshia\BattingEdge_FYP\backend\models\battingedge_V9_5_bigru_best.keras
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 83s 285ms/step - accuracy: 0.8553 - loss: 0.4095 - val_accuracy: 0.8505 - val_loss: 0.4512 - learning_rate: 5.0000e-04
# Epoch 17/60
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - accuracy: 0.8893 - loss: 0.3547
# Epoch 17: val_accuracy did not improve from 0.85052
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 53s 284ms/step - accuracy: 0.8786 - loss: 0.3701 - val_accuracy: 0.8273 - val_loss: 0.5321 - learning_rate: 5.0000e-04
# Epoch 18/60
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step - accuracy: 0.8831 - loss: 0.3310
# Epoch 18: val_accuracy did not improve from 0.85052
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 82s 282ms/step - accuracy: 0.8813 - loss: 0.3460 - val_accuracy: 0.8479 - val_loss: 0.4706 - learning_rate: 5.0000e-04
# Epoch 19/60
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - accuracy: 0.8879 - loss: 0.3304
# Epoch 19: val_accuracy did not improve from 0.85052
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 83s 285ms/step - accuracy: 0.8863 - loss: 0.3414 - val_accuracy: 0.8402 - val_loss: 0.4417 - learning_rate: 5.0000e-04
# Epoch 20/60
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - accuracy: 0.9088 - loss: 0.2929
# Epoch 20: val_accuracy improved from 0.85052 to 0.86856, saving model to D:\Users\Anoshia\BattingEdge_FYP\backend\models\battingedge_V9_5_bigru_best.keras
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 54s 286ms/step - accuracy: 0.9042 - loss: 0.2983 - val_accuracy: 0.8686 - val_loss: 0.4193 - learning_rate: 5.0000e-04
# Epoch 21/60
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step - accuracy: 0.9137 - loss: 0.2678
# Epoch 21: val_accuracy did not improve from 0.86856
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 54s 287ms/step - accuracy: 0.9132 - loss: 0.2715 - val_accuracy: 0.8376 - val_loss: 0.4942 - learning_rate: 5.0000e-04
# Epoch 22/60
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step - accuracy: 0.9110 - loss: 0.2768
# Epoch 22: val_accuracy did not improve from 0.86856
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 54s 287ms/step - accuracy: 0.9066 - loss: 0.2919 - val_accuracy: 0.8660 - val_loss: 0.4135 - learning_rate: 5.0000e-04
# Epoch 23/60
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - accuracy: 0.9181 - loss: 0.2480
# Epoch 23: val_accuracy improved from 0.86856 to 0.87113, saving model to D:\Users\Anoshia\BattingEdge_FYP\backend\models\battingedge_V9_5_bigru_best.keras
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 82s 286ms/step - accuracy: 0.9195 - loss: 0.2456 - val_accuracy: 0.8711 - val_loss: 0.4070 - learning_rate: 5.0000e-04
# Epoch 24/60
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step - accuracy: 0.9192 - loss: 0.2279
# Epoch 24: val_accuracy improved from 0.87113 to 0.87887, saving model to D:\Users\Anoshia\BattingEdge_FYP\backend\models\battingedge_V9_5_bigru_best.keras
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 55s 290ms/step - accuracy: 0.9165 - loss: 0.2429 - val_accuracy: 0.8789 - val_loss: 0.4377 - learning_rate: 5.0000e-04
# Epoch 25/60
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step - accuracy: 0.9343 - loss: 0.1903
# Epoch 25: val_accuracy did not improve from 0.87887
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 54s 289ms/step - accuracy: 0.9292 - loss: 0.2013 - val_accuracy: 0.8531 - val_loss: 0.4822 - learning_rate: 5.0000e-04
# Epoch 26/60
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step - accuracy: 0.9305 - loss: 0.2040
# Epoch 26: val_accuracy improved from 0.87887 to 0.89433, saving model to D:\Users\Anoshia\BattingEdge_FYP\backend\models\battingedge_V9_5_bigru_best.keras
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 55s 290ms/step - accuracy: 0.9278 - loss: 0.2102 - val_accuracy: 0.8943 - val_loss: 0.3825 - learning_rate: 5.0000e-04
# Epoch 27/60
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step - accuracy: 0.9283 - loss: 0.2211
# Epoch 27: val_accuracy did not improve from 0.89433
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 55s 292ms/step - accuracy: 0.9325 - loss: 0.1932 - val_accuracy: 0.8711 - val_loss: 0.4343 - learning_rate: 5.0000e-04
# Epoch 28/60
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - accuracy: 0.9428 - loss: 0.1713
# Epoch 28: val_accuracy did not improve from 0.89433
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 82s 291ms/step - accuracy: 0.9428 - loss: 0.1702 - val_accuracy: 0.8814 - val_loss: 0.4581 - learning_rate: 5.0000e-04
# Epoch 29/60
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step - accuracy: 0.9479 - loss: 0.1742
# Epoch 29: val_accuracy did not improve from 0.89433
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 55s 292ms/step - accuracy: 0.9421 - loss: 0.1894 - val_accuracy: 0.8737 - val_loss: 0.5045 - learning_rate: 5.0000e-04
# Epoch 30/60
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step - accuracy: 0.9432 - loss: 0.1670
# Epoch 30: val_accuracy did not improve from 0.89433
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 56s 296ms/step - accuracy: 0.9458 - loss: 0.1628 - val_accuracy: 0.8840 - val_loss: 0.4048 - learning_rate: 5.0000e-04
# Epoch 31/60
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step - accuracy: 0.9543 - loss: 0.1437
# Epoch 31: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 31: val_accuracy did not improve from 0.89433
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 56s 296ms/step - accuracy: 0.9451 - loss: 0.1613 - val_accuracy: 0.8660 - val_loss: 0.5052 - learning_rate: 5.0000e-04
# Epoch 32/60
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step - accuracy: 0.9570 - loss: 0.1256
# Epoch 32: val_accuracy improved from 0.89433 to 0.90979, saving model to D:\Users\Anoshia\BattingEdge_FYP\backend\models\battingedge_V9_5_bigru_best.keras
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 82s 295ms/step - accuracy: 0.9598 - loss: 0.1165 - val_accuracy: 0.9098 - val_loss: 0.3852 - learning_rate: 2.5000e-04
# Epoch 33/60
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step - accuracy: 0.9667 - loss: 0.1061
# Epoch 33: val_accuracy did not improve from 0.90979
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 82s 296ms/step - accuracy: 0.9684 - loss: 0.1042 - val_accuracy: 0.9072 - val_loss: 0.3762 - learning_rate: 2.5000e-04
# Epoch 34/60
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step - accuracy: 0.9699 - loss: 0.0955
# Epoch 34: val_accuracy did not improve from 0.90979
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 84s 307ms/step - accuracy: 0.9737 - loss: 0.0863 - val_accuracy: 0.9098 - val_loss: 0.3786 - learning_rate: 2.5000e-04
# Epoch 35/60
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - accuracy: 0.9755 - loss: 0.0836
# Epoch 35: val_accuracy did not improve from 0.90979
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 85s 322ms/step - accuracy: 0.9754 - loss: 0.0810 - val_accuracy: 0.9046 - val_loss: 0.4231 - learning_rate: 2.5000e-04
# Epoch 36/60
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step - accuracy: 0.9782 - loss: 0.0719
# Epoch 36: val_accuracy did not improve from 0.90979
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 78s 298ms/step - accuracy: 0.9810 - loss: 0.0676 - val_accuracy: 0.8995 - val_loss: 0.4172 - learning_rate: 2.5000e-04
# Epoch 37/60
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step - accuracy: 0.9791 - loss: 0.0720
# Epoch 37: val_accuracy did not improve from 0.90979
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 83s 303ms/step - accuracy: 0.9771 - loss: 0.0759 - val_accuracy: 0.9021 - val_loss: 0.4782 - learning_rate: 2.5000e-04
# Epoch 38/60
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step - accuracy: 0.9840 - loss: 0.0592
# Epoch 38: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 38: val_accuracy did not improve from 0.90979
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 55s 292ms/step - accuracy: 0.9790 - loss: 0.0693 - val_accuracy: 0.9098 - val_loss: 0.4106 - learning_rate: 2.5000e-04
# Epoch 39/60
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step - accuracy: 0.9832 - loss: 0.0597
# Epoch 39: val_accuracy did not improve from 0.90979
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 56s 298ms/step - accuracy: 0.9820 - loss: 0.0605 - val_accuracy: 0.9072 - val_loss: 0.4327 - learning_rate: 1.2500e-04
# Epoch 40/60
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step - accuracy: 0.9838 - loss: 0.0574
# Epoch 40: val_accuracy did not improve from 0.90979
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 81s 290ms/step - accuracy: 0.9804 - loss: 0.0659 - val_accuracy: 0.9021 - val_loss: 0.4491 - learning_rate: 1.2500e-04
# Epoch 41/60
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step - accuracy: 0.9825 - loss: 0.0539
# Epoch 41: val_accuracy improved from 0.90979 to 0.91495, saving model to D:\Users\Anoshia\BattingEdge_FYP\backend\models\battingedge_V9_5_bigru_best.keras
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 61s 322ms/step - accuracy: 0.9827 - loss: 0.0547 - val_accuracy: 0.9149 - val_loss: 0.4527 - learning_rate: 1.2500e-04
# Epoch 42/60
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - accuracy: 0.9858 - loss: 0.0511
# Epoch 42: val_accuracy did not improve from 0.91495
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 90s 361ms/step - accuracy: 0.9864 - loss: 0.0509 - val_accuracy: 0.9098 - val_loss: 0.4690 - learning_rate: 1.2500e-04
# Epoch 43/60
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step - accuracy: 0.9871 - loss: 0.0469
# Epoch 43: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 43: val_accuracy did not improve from 0.91495
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 73s 314ms/step - accuracy: 0.9877 - loss: 0.0449 - val_accuracy: 0.9072 - val_loss: 0.5016 - learning_rate: 1.2500e-04
# Epoch 43: early stopping
# Restoring model weights from the end of the best epoch: 33.
#
# ======================================================================
# ✅ TRAINING COMPLETE
# ======================================================================
#
# 💾 Saved final model: battingedge_V9_5_bigru_final.keras
#
# ======================================================================
# 📊 EVALUATING ON TEST SET
# ======================================================================
#
# ✅ Loaded best model from: battingedge_V9_5_bigru_best.keras
#
# 📋 CLASSIFICATION REPORT:
#
#               precision    recall  f1-score   support
#
#  Cover Drive      0.887     0.910     0.899        78
#     Cut Shot      0.880     0.901     0.890        81
#      Defense      0.973     0.960     0.966        75
#    Pull Shot      0.955     0.887     0.920        71
#   Sweep Shot      0.907     0.932     0.919        73
#
#     accuracy                          0.918       378
#    macro avg      0.920     0.918     0.919       378
# weighted avg      0.919     0.918     0.918       378
#
# ✅ Report saved: report_V9_5_bigru.txt
#
# 🔢 CONFUSION MATRIX:
#    (Rows = True, Cols = Predicted)
#
#          Cove  Cut   Defe  Pull  Swee
# Cover Dr   71     3     0     0     4
# Cut Shot    4    73     1     3     0
# Defense     1     0    72     0     2
# Pull Sho    1     6     0    63     1
# Sweep Sh    3     1     1     0    68
#
# 📈 PER-CLASS ACCURACY:
#
#    Cover Drive    :  71/ 78 =  91.0%
#    Cut Shot       :  73/ 81 =  90.1%
#    Defense        :  72/ 75 =  96.0%
#    Pull Shot      :  63/ 71 =  88.7%
#    Sweep Shot     :  68/ 73 =  93.2%
#
#    OVERALL        : 347/378 = 91.80%
#
# 🔍 MAJOR CONFUSIONS (>3 cases):
#
#    Pull Shot       → Cut Shot       : 6 cases
#    Cover Drive     → Sweep Shot     : 4 cases
#    Cut Shot        → Cover Drive    : 4 cases
#
# 📊 Generating visualizations...
#    ✅ Saved: confusion_matrix_V9_5_bigru.png
#    ✅ Saved: training_history_V9_5_bigru.png
#
# ======================================================================
# 🎉 V9.5 (bigru) TRAINING COMPLETE
# ======================================================================
#
# 📦 Saved artifacts:
#    1. Best model: battingedge_V9_5_bigru_best.keras
#    2. Final model: battingedge_V9_5_bigru_final.keras
#    3. Metadata: metadata_V9_5_bigru.json
#
# ✨ EXCELLENT RESULT! GRU is efficient and accurate.
# ======================================================================
